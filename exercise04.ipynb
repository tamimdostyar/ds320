# %% [markdown]
# <a href="https://colab.research.google.com/github/TamimDostyar/ds320/blob/main/exercise04.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Before you turn this problem in, make sure everything runs as expected. First, **restart the kernel** (in the menubar, select Kernel$\rightarrow$Restart) and then **run all cells** (in the menubar, select Cell$\rightarrow$Run All).
#
# Make sure you fill in any place that says `YOUR CODE HERE` or "YOUR ANSWER HERE", as well as your name and collaborators below:

# %%
NAME = "Ahmad Tamim Dostyar"
COLLABORATORS = ""

# %% [markdown]
# ---

# %% [markdown]
# # DS320, excercise 04
#
# This exercise focuses on joining and summarizing to get insights from data. You will work with the MovieLens1M data set. All the data is in the `data` folder.
#
# You need to read the README file carefully to undersand the data set.
#
# There are 10 tasks, each is worth 10 points. You will get 100/100 for the maximum score of this exercise.
#
# For each `task i` (except `task 1`) create a variable `ti` to store the outcomes of that task. For example, store the outcome of `task 01` in a variable, called `t1`.
#
# Note: I will mannually grade your code, so no test case will be provided, but I will give you some hints.

# %%
# !ls
# Out:
# sample_data

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %% [markdown]
# # Task 01:
# read all 3 .dat files into 3 dfs. drop all rows with missing values
# print the shapes of all dfs.
# expectation: (6040, 5) (1000209, 4) (3883, 3)

# %%
try:
  data = "/content/drive/MyDrive/data"
except:
  data = "data"
print(data)
# Out:
# MyDrive/data
# ls: cannot access 'MyDrive/data': No such file or directory

# %% [markdown]
# # Task 02:
# how many users who rate at least one movie
# expectation: 6040

# %%
# YOUR CODE HERE
raise NotImplementedError()

# %% [markdown]
# # Task 03:
# how many movies which have no ratings
# Expectation: 177

# %%
# YOUR CODE HERE
raise NotImplementedError()

# %% [markdown]
# # Task 04:
# Show top 10 movies (movie_id, title, genres, and the count of ratings) have the most frequency of ratings. For example if you have 3 movies: movie 1 has 10 ratings, movie 2 has 20 ratings and movie 3 has 30 ratings, then top 2 movies have the most frequency of ratings is movie 3 and movie 2.
# Expectation: a dataframe with shape = (10, 4)

# %%
# YOUR CODE HERE
raise NotImplementedError()

# %% [markdown]
# # Task 05:
# Compute mean movie ratings for each movie grouped by gender (should use DataFrame.pivot_table())
# Use movie title as index for the resulted df.
#
# Expectation: a dataframe with shape = (3706, 2)

# %%
# YOUR CODE HERE
raise NotImplementedError()

# %% [markdown]
# # Task 06:
# Show top 10 highest mean rating movies (movie_id, title, genres, and the count of ratings), rated by women

# %%
# YOUR CODE HERE
raise NotImplementedError()

# %% [markdown]
# # Task 07:
# Compute counts of ratings for movies grouped by genres and age. Show the resuted df with row index = genres, columns' names = age
#
# Note that one movie can be in more than one genres. For example "24 7: Twenty Four Seven (1997)" has "Comedy|Drama" for genres.
#
# Hint: Use DataFrame.explode(), DataFrame.groupby(), and Series.unstack()
# expectation: a dataframe with shape = (18, 7) 18 means 18 values in the `genres` column, 7 means 7 values in the `age` column

# %%
# YOUR CODE HERE
raise NotImplementedError()

# %% [markdown]
# # Task 08:
# From Task 7, what genre get the most count?

# %%
# YOUR CODE HERE
raise NotImplementedError()

# %% [markdown]
# # Task 09:
# What age gives the most count?

# %%
# YOUR CODE HERE
raise NotImplementedError()

# %% [markdown]
# # Task 10
# From the resulted age in Task 9, show all the counts made by that age in the descending order

# %%
# YOUR CODE HERE
raise NotImplementedError()
